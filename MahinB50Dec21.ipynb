# %% [markdown]
# <a href="https://colab.research.google.com/github/mahin307/Python-practice-/blob/main/MahinB50Dec21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python casting**

# %%
#Integers:
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x,y,z)
#Floats:
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2
print(x,y,z,w)
#Strings:
x = str("s1") # x will be 's1'
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'
print(x,y,z)
# Out:
# 1 2 3
# 1.0 2.8 3.0 4.2
# s1 2 3.0

# %% [markdown]
# **Python Strings**

# %%
print("Hello")
print('Hello')
#Quotes Inside Quotes
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
#Assign String to a Variable
a = "Hello"
print(a)
#Multiline Strings
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
#three single quotes:
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
#Get the character at position 1
a = "Hello, World!"
print(a[1])
## Looping Through a String
for x in "banana":
    print(x)

# String Length
a = "Hello, World!"
print(len(a))

# Check String (Keyword: in)
txt = "The best things in life are free!"
print("free" in txt)

# Use in in an if Statement
if "free" in txt:
    print("Yes, 'free' is present.")

# Check if NOT (Keyword: not in)
print("expensive" not in txt)

# Use not in in an if Statement
if "expensive" not in txt:
    print("No, 'expensive' is NOT present.")

# Slice a String
b = "Hello, World!"
print(b[2:5])  # Characters from position 2 to 5 (not included)

# Slice From the Start
print(b[:5])  # Characters from the start to position 5 (not included)

# Slice To the End
print(b[2:])  # Characters from position 2 to the end

# Negative Indexing
print(b[-5:-2])  # Characters from position -5 to -2 (not included)
#modify String
# Convert to Upper Case
a = "Hello, World!"
print(a.upper())

# Convert to Lower Case
print(a.lower())

# Remove Whitespace
a = " Hello, World! "
print(a.strip())  # Returns "Hello, World!"

# Replace a String
a = "Hello, World!"
print(a.replace("H", "J"))

# Split a String
print(a.split(","))  # Returns ['Hello', ' World!']
# Concatenate two strings
a = "Hello"
b = "World"
c = a + b
print(c)

# Concatenate two strings with a space
c = a + " " + b
print(c)
# Incorrect concatenation of strings and numbers (will raise an error)
age = 36
# txt = "My name is John, I am " + age
# print(txt)

# Correct: Using f-strings for formatting
age = 36
txt = f"My name is John, I am {age}"
print(txt)

# Add a placeholder for a variable
price = 59
txt = f"The price is {price} dollars"
print(txt)

# Display the price with 2 decimals
txt = f"The price is {price:.2f} dollars"
print(txt)

# Perform a math operation in the placeholder
txt = f"The price is {20 * 59} dollars"
print(txt)
# Using escape characters to include double quotes in a string
txt = "We are the so-called \"Vikings\" from the north."
print(txt)

# Other escape characters in Python
single_quote = 'It\'s a sunny day'  # Single Quote
backslash = "This is a backslash: \\"  # Backslash
new_line = "Hello\nWorld"  # New Line
carriage_return = "Hello\rWorld"  # Carriage Return
tab = "Hello\tWorld"  # Tab
backspace = "Hello\bWorld"  # Backspace
form_feed = "Hello\fWorld"  # Form Feed
octal_value = "\110\145\154\154\157"  # Octal value for "Hello"
hex_value = "\x48\x65\x6C\x6C\x6F"  # Hex value for "Hello"

# Print examples
print(single_quote)
print(backslash)
print(new_line)
print(carriage_return)
print(tab)
print(backspace)
print(form_feed)
print(octal_value)
print(hex_value)
# Out:
# Hello
# Hello
# It's alright
# He is called 'Johnny'
# He is called "Johnny"
# Hello
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.
# e
# b
# a
# n
# a
# n
# a
# 13
# True
# Yes, 'free' is present.
# True
# No, 'expensive' is NOT present.
# llo
# Hello
# llo, World!
# orl
# HELLO, WORLD!
# hello, world!
# Hello, World!
# Jello, World!
# ['Hello', ' World!']
# HelloWorld
# Hello World
# My name is John, I am 36
# The price is 59 dollars
# The price is 59.00 dollars
# The price is 1180 dollars

# %% [markdown]
# **Bolean**

# %%
# Comparison operations
print(10 > 9)
print(10 == 9)
print(10 < 9)

# Using if statement to evaluate condition
a = 200
b = 33
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")

# Evaluate values using bool()
print(bool("Hello"))
print(bool(15))

# Evaluate two variables
x = "Hello"
y = 15
print(bool(x))
print(bool(y))

# Examples of True values
print(bool("abc"))
print(bool(123))
print(bool(["apple", "cherry", "banana"]))

# Examples of False values
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))

# Custom object with __len__ method
class myclass():
    def __len__(self):
        return 0

myobj = myclass()
print(bool(myobj))

# Function that returns a boolean value
def myFunction():
    return True

print(myFunction())

# Execute code based on the boolean return of a function
if myFunction():
    print("YES!")
else:
    print("NO!")

# Using isinstance() to check the type of an object
x = 200
print(isinstance(x, int))

# Exercise: result of comparison
print(5 > 3)  # True

# %% [markdown]
# **Operator**

# %%
# Python Operators

# Arithmetic Operators
print(10 + 5)  # Addition
print(10 - 5)  # Subtraction
print(10 * 5)  # Multiplication
print(10 / 5)  # Division
print(10 % 3)  # Modulus
print(10 ** 2) # Exponentiation
print(10 // 3) # Floor division

# Assignment Operators
x = 5
x += 3  # x = x + 3
x -= 3  # x = x - 3
x *= 3  # x = x * 3
x /= 3  # x = x / 3
x %= 3  # x = x % 3
x //= 3  # x = x // 3
x **= 3  # x = x ** 3
print(x := 3)  # x = 3

# Comparison Operators
print(10 == 9)   # Equal
print(10 != 9)   # Not equal
print(10 > 9)    # Greater than
print(10 < 9)    # Less than
print(10 >= 9)   # Greater than or equal to
print(10 <= 9)   # Less than or equal to

# Logical Operators
print(10 < 5 and 10 < 10)  # AND
print(10 < 5 or 10 < 10)   # OR
print(not(10 < 5 and 10 < 10))  # NOT

# Identity Operators
x = [1, 2, 3]
y = [1, 2, 3]
print(x is y)  # Same object
print(x is not y)  # Not the same object

# Membership Operators
x = ["apple", "banana", "cherry"]
print("banana" in x)  # True
print("orange" not in x)  # True

# Bitwise Operators
x = 10  # 1010 in binary
y = 4   # 0100 in binary
print(x & y)  # AND
print(x | y)  # OR
print(x ^ y)  # XOR
print(~x)     # NOT
print(x << 2)  # Left Shift
print(x >> 2)  # Right Shift

# Operator Precedence
print((6 + 3) - (6 + 3))  # Parentheses
print(100 + 5 * 3)  # Multiplication before addition
print(5 + 4 - 7 + 3)  # Addition and subtraction from left to right
# Out:
# 15
# 5
# 50
# 2.0
# 1
# 100
# 3
# 3
# False
# True
# True
# False
# True
# False
# False
# False
# True
# False
# True
# True
# True
# 0
# 14
# 14
# -11
# 40
# 2
# 0
# 115
# 5
